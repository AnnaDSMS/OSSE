# %%
import skill_metrics as sm

import numpy as np
import matplotlib.pylab as plt
import matplotlib.patches as mpatches
from matplotlib.ticker import MaxNLocator
from pylab import *

# %%
file_STD_mean = '/Users/annasommer/Documents/Documents/OSSE_Project/Data_for_plot/STD_mean_TD.txt'
file_Corr_mean = '/Users/annasommer/Documents/Documents/OSSE_Project/Data_for_plot/Corr_mean_TD.txt'
file_RMSE_mean = '/Users/annasommer/Documents/Documents/OSSE_Project/Data_for_plot/RMSE_mean_TD.txt'
file_RMSE_cent_mean = '/Users/annasommer/Documents/Documents/OSSE_Project/Data_for_plot/RMSE_cent_mean_TD.txt'

with open(file_STD_mean) as f:
        rows = [[str(x) for x in line.split(';')] for line in f]
        biome_mean_STD,model_mean_STD,STD_mean = [list(col) for col in zip(*rows)] 
        f.close()
        
with open(file_Corr_mean) as f:
        rows = [[str(x) for x in line.split(';')] for line in f]
        biome_mean,model_mean,Corr_mean = [list(col) for col in zip(*rows)] 
        f.close()

with open(file_RMSE_mean) as f:
        rows = [[str(x) for x in line.split(';')] for line in f]
        biome_mean,model_mean,RMSE_mean = [list(col) for col in zip(*rows)] 
        f.close()

with open(file_RMSE_cent_mean) as f:
        rows = [[str(x) for x in line.split(';')] for line in f]
        biome_mean,model_mean,RMSE_cent_mean = [list(col) for col in zip(*rows)] 
        f.close()
        
file_STD_all = '/Users/annasommer/Documents/Documents/OSSE_Project/Data_for_plot/STD_all_TD.txt'
file_Corr_all = '/Users/annasommer/Documents/Documents/OSSE_Project/Data_for_plot/Corr_all_TD.txt'
file_RMSE_all = '/Users/annasommer/Documents/Documents/OSSE_Project/Data_for_plot/RMSE_all_TD.txt'
file_RMSE_cent_all = '/Users/annasommer/Documents/Documents/OSSE_Project/Data_for_plot/RMSE_cent_all_TD.txt'

with open(file_STD_all) as f:
        rows = [[str(x) for x in line.split(';')] for line in f]
        biome_all,model_all,k_numb,STD_all = [list(col) for col in zip(*rows)] 
        f.close()
        
with open(file_Corr_all) as f:
        rows = [[str(x) for x in line.split(';')] for line in f]
        biome_all,model_all,k_numb,Corr_all = [list(col) for col in zip(*rows)] 
        f.close()

with open(file_RMSE_all) as f:
        rows = [[str(x) for x in line.split(';')] for line in f]
        biome_all,model_all,k_numb,RMSE_all = [list(col) for col in zip(*rows)] 
        f.close()

with open(file_RMSE_cent_all) as f:
        rows = [[str(x) for x in line.split(';')] for line in f]
        biome_all,model_all,k_numb,RMSE_cent_all = [list(col) for col in zip(*rows)] 
        f.close()        
        
biome_mean_STD = np.array(biome_mean_STD)
biome_mean_STD = biome_mean_STD.astype(np.float)
model_mean_STD = np.array(model_mean_STD)
model_mean_STD = model_mean_STD.astype(np.float)
biome_mean = np.array(biome_mean)
biome_mean = biome_mean.astype(np.float)
model_mean = np.array(model_mean)
model_mean = model_mean.astype(np.float)

STD_mean = np.array(STD_mean)
STD_mean = STD_mean.astype(np.float)
Corr_mean = np.array(Corr_mean)
Corr_mean = Corr_mean.astype(np.float)
RMSE_mean = np.array(RMSE_mean)
RMSE_mean = RMSE_mean.astype(np.float)
RMSE_cent_mean = np.array(RMSE_cent_mean)
RMSE_cent_mean = RMSE_cent_mean.astype(np.float)

biome_all = np.array(biome_all)
biome_all = biome_all.astype(np.float)
model_all = np.array(model_all)
model_all = model_all.astype(np.float)
k_numb = np.array(k_numb)
k_numb = k_numb.astype(np.float)

STD_all = np.array(STD_all)
STD_all = STD_all.astype(np.float)
Corr_all = np.array(Corr_all)
Corr_all = Corr_all.astype(np.float)
RMSE_all = np.array(RMSE_all)
RMSE_all = RMSE_all.astype(np.float)
RMSE_cent_all = np.array(RMSE_cent_all)
RMSE_cent_all = RMSE_cent_all.astype(np.float)

# %%
biome_numb = [0,9,10,11,12,13,15,16,17]

# %%
STD_mean_tot = np.zeros((12,9))
Corr_mean_tot = np.zeros((12,9))
RMSE_mean_tot = np.zeros((12,9))
RMSE_cent_mean_tot = np.zeros((12,9))

STD_all_tot = np.zeros((12,4,9))
Corr_all_tot = np.zeros((12,4,9))
RMSE_all_tot = np.zeros((12,4,9))
RMSE_cent_all_tot = np.zeros((12,4,9))

for i in np.arange(0,12,1):
    p = 0
    for j in biome_numb:
        p = p + 1
        for k in np.arange(0,len(STD_mean),1):
            if i == int(model_mean_STD[k]) and j == int(biome_mean_STD[k]):
                STD_mean_tot[i,p-1] = STD_mean[k]
                break
                
for i in np.arange(0,12,1):
    p = 0
    for j in biome_numb:
        p = p + 1
        for k in np.arange(0,len(Corr_mean),1):
            if i == 0:
                Corr_mean_tot[i,p-1] = 1.
                RMSE_mean_tot[i,p-1] = 0.
                RMSE_cent_mean_tot[i,p-1] = 0.
                break 
            if i == int(model_mean[k]) and j == int(biome_mean[k]):                
                Corr_mean_tot[i,p-1] = Corr_mean[k]
                RMSE_mean_tot[i,p-1] = RMSE_mean[k]
                RMSE_cent_mean_tot[i,p-1] = RMSE_cent_mean[k]
                break

for i in np.arange(0,12,1):
    p = 0
    for j in biome_numb:
        p = p + 1
        for n in np.arange(0,4,1):
            for k in np.arange(0,len(Corr_mean),1):
                if i == 0:
                    STD_all_tot[i,n,p-1] = STD_mean_tot[0,p-1]
                    Corr_all_tot[i,n,p-1] = 1.
                    RMSE_all_tot[i,n,p-1] = 0.
                    RMSE_cent_all_tot[i,n,p-1] = 0.
                    break 
                if i == int(model_mean[k]) and j == int(biome_mean[k]) and n == int(k_numb[k]):   
                    STD_all_tot[i,n,p-1] = STD_all[k]
                    Corr_all_tot[i,n,p-1] = Corr_all[k]
                    RMSE_all_tot[i,n,p-1] = RMSE_all[k]
                    RMSE_cent_all_tot[i,n,p-1] = RMSE_cent_all[k]
                    break

# %%
Models_Name = ['Obs','OSSE 1','OSSE 2','OSSE 3','OSSE 4','OSSE 5','OSSE 6','OSSE 7','OSSE 8','OSSE 9','OSSE 10','OSSE 11']
Color_biomes = ['b','r','k','g','b','m','c','r','k']
symbol_list = ['+','o','x','s','d','^','v','p','h','*','1']
size_marker = [15,10,15,10,10,10,10,10,10,15,10]
list_edgewidth = [3,1,3,1,1,1,1,1,1,3,1]

# %%
#sm.taylor_diagram(Diff_Std[1,:],RMSE[1,:],Corr[1,:],markerColor = 'b')
for i in np.arange(0,9,1):
    sm.taylor_diagram(STD_mean_tot[:,i],RMSE_cent_mean_tot[:,i],Corr_mean_tot[:,i],\
                      markerLabel = Models_Name,markerLabelColor = 'black',markercolor = Color_biomes[i], \
                      markerLegend = 'on',markerSize=10,\
                      titleRMS = 'off', showlabelsRMS = 'off', tickRMS =[0.0],colCOR='grey',\
                      styleOBS='-',colOBS = Color_biomes[i],alpha=0.0)
#sm.taylor_diagram(Diff_Std[1,:],RMSE[1,:],Corr[1,:],markerColor = 'b')
plt.savefig('taylor_legend_new.png',dpi=450,facecolor='w')

# %%
STD_mean_tot_new = np.zeros((11,10))
RMSE_cent_mean_tot_new = np.zeros((11,10))
Corr_mean_tot_new = np.zeros((11,10))

STD_mean_tot_new[:,1:10] = STD_mean_tot[1:12,:]
RMSE_cent_mean_tot_new[:,1:10] = RMSE_cent_mean_tot[1:12,:]
Corr_mean_tot_new[:,1:10] = Corr_mean_tot[1:12,:]

for i in np.arange(0,11,1):
    if i < 9:
        STD_mean_tot_new[i,0] = STD_mean_tot[0,i]
    else:
        STD_mean_tot_new[i,0] = STD_mean_tot[0,i-9]
        
Corr_mean_tot_new[:,0] = 1.

# %%
Color_per_biomes = ['fuchsia','cyan','palegreen','mediumseagreen','darkgreen','limegreen','orange','orangered','darkred']

# %%
for i in np.arange(0,11,1):
    for j in np.arange(1,10,1):
        STD_to_plot = np.zeros(2)
        RMSE_cent_to_plot = np.zeros(2)
        Corr_to_plot = np.zeros(2)
        STD_to_plot[0] = STD_mean_tot_new[i,0]
        RMSE_cent_to_plot[0] = RMSE_cent_mean_tot_new[i,0]
        Corr_to_plot[0] = Corr_mean_tot_new[i,0]
        STD_to_plot[1] = STD_mean_tot_new[i,j]
        RMSE_cent_to_plot[1] = RMSE_cent_mean_tot_new[i,j]
        Corr_to_plot[1] = Corr_mean_tot_new[i,j]
        if j-1 == i :
            sm.taylor_diagram(STD_to_plot,RMSE_cent_to_plot,Corr_to_plot,\
                              markerLabelColor = 'black',markercolor = Color_per_biomes[j-1], \
                              markerSize=size_marker[i],symbol = symbol_list[i],edgewidth = list_edgewidth[i],\
                              titleRMS = 'off', showlabelsRMS = 'off', tickRMS =[0.0],colCOR='grey',\
                              styleOBS='-',colOBS = Color_per_biomes[j-1],alpha=0.0)
        else:
            sm.taylor_diagram(STD_to_plot,RMSE_cent_to_plot,Corr_to_plot,\
                              markerLabelColor = 'black',markercolor = Color_per_biomes[j-1], \
                              markerSize=size_marker[i],symbol = symbol_list[i],edgewidth = list_edgewidth[i],\
                              titleRMS = 'off', showlabelsRMS = 'off', tickRMS =[0.0],colCOR='grey',\
                              alpha=0.0)

plt.savefig('taylor_for_article_new.png',dpi=450,facecolor='w')

# %%
for j in np.arange(1,10,1):
    i = 0
    STD_to_plot = np.zeros(2)
    RMSE_cent_to_plot = np.zeros(2)
    Corr_to_plot = np.zeros(2)
    STD_to_plot[0] = STD_mean_tot_new[j-1,0]
    RMSE_cent_to_plot[0] = RMSE_cent_mean_tot_new[j-1,0]
    Corr_to_plot[0] = Corr_mean_tot_new[j-1,0]
    STD_to_plot[1] = STD_mean_tot_new[i,j]
    RMSE_cent_to_plot[1] = RMSE_cent_mean_tot_new[i,j]
    Corr_to_plot[1] = Corr_mean_tot_new[i,j]
    sm.taylor_diagram(STD_to_plot,RMSE_cent_to_plot,Corr_to_plot,\
                      markerLabelColor = 'black',markercolor = Color_per_biomes[j-1], \
                      markerSize=size_marker[i],symbol = symbol_list[i],edgewidth = 3,\
                      titleRMS = 'off', showlabelsRMS = 'off', tickRMS =[0.0],colCOR='grey',\
                      styleOBS='-',colOBS = Color_per_biomes[j-1],alpha=0.0)
    
plt.savefig('taylor_for_article_OSSE1_new.png',dpi=450,facecolor='w')

# %%
for j in np.arange(1,10,1):
    i = 1
    STD_to_plot = np.zeros(2)
    RMSE_cent_to_plot = np.zeros(2)
    Corr_to_plot = np.zeros(2)
    STD_to_plot[0] = STD_mean_tot_new[j-1,0]
    RMSE_cent_to_plot[0] = RMSE_cent_mean_tot_new[j-1,0]
    Corr_to_plot[0] = Corr_mean_tot_new[j-1,0]
    STD_to_plot[1] = STD_mean_tot_new[i,j]
    RMSE_cent_to_plot[1] = RMSE_cent_mean_tot_new[i,j]
    Corr_to_plot[1] = Corr_mean_tot_new[i,j]
    sm.taylor_diagram(STD_to_plot,RMSE_cent_to_plot,Corr_to_plot,\
                      markerLabelColor = 'black',markercolor = Color_per_biomes[j-1], \
                      markerSize=size_marker[i],symbol = symbol_list[i],edgewidth = 3,\
                      titleRMS = 'off', showlabelsRMS = 'off', tickRMS =[0.0],colCOR='grey',\
                      styleOBS='-',colOBS = Color_per_biomes[j-1],alpha=0.0)
    
plt.savefig('taylor_for_article_OSSE2_new.png',dpi=450,facecolor='w')

# %%
for j in np.arange(1,10,1):
    i = 2
    STD_to_plot = np.zeros(2)
    RMSE_cent_to_plot = np.zeros(2)
    Corr_to_plot = np.zeros(2)
    STD_to_plot[0] = STD_mean_tot_new[j-1,0]
    RMSE_cent_to_plot[0] = RMSE_cent_mean_tot_new[j-1,0]
    Corr_to_plot[0] = Corr_mean_tot_new[j-1,0]
    STD_to_plot[1] = STD_mean_tot_new[i,j]
    RMSE_cent_to_plot[1] = RMSE_cent_mean_tot_new[i,j]
    Corr_to_plot[1] = Corr_mean_tot_new[i,j]
    sm.taylor_diagram(STD_to_plot,RMSE_cent_to_plot,Corr_to_plot,\
                      markerLabelColor = 'black',markercolor = Color_per_biomes[j-1], \
                      markerSize=size_marker[i],symbol = symbol_list[i],edgewidth = 3,\
                      titleRMS = 'off', showlabelsRMS = 'off', tickRMS =[0.0],colCOR='grey',\
                      styleOBS='-',colOBS = Color_per_biomes[j-1],alpha=0.0)
    
plt.savefig('taylor_for_article_OSSE3_new.png',dpi=450,facecolor='w')

# %%
for j in np.arange(1,10,1):
    i = 3
    STD_to_plot = np.zeros(2)
    RMSE_cent_to_plot = np.zeros(2)
    Corr_to_plot = np.zeros(2)
    STD_to_plot[0] = STD_mean_tot_new[j-1,0]
    RMSE_cent_to_plot[0] = RMSE_cent_mean_tot_new[j-1,0]
    Corr_to_plot[0] = Corr_mean_tot_new[j-1,0]
    STD_to_plot[1] = STD_mean_tot_new[i,j]
    RMSE_cent_to_plot[1] = RMSE_cent_mean_tot_new[i,j]
    Corr_to_plot[1] = Corr_mean_tot_new[i,j]
    sm.taylor_diagram(STD_to_plot,RMSE_cent_to_plot,Corr_to_plot,\
                      markerLabelColor = 'black',markercolor = Color_per_biomes[j-1], \
                      markerSize=size_marker[i],symbol = symbol_list[i],edgewidth = 3,\
                      titleRMS = 'off', showlabelsRMS = 'off', tickRMS =[0.0],colCOR='grey',\
                      styleOBS='-',colOBS = Color_per_biomes[j-1],alpha=0.0)
    
plt.savefig('taylor_for_article_OSSE4_new.png',dpi=450,facecolor='w')

# %%
for j in np.arange(1,10,1):
    i = 4
    STD_to_plot = np.zeros(2)
    RMSE_cent_to_plot = np.zeros(2)
    Corr_to_plot = np.zeros(2)
    STD_to_plot[0] = STD_mean_tot_new[j-1,0]
    RMSE_cent_to_plot[0] = RMSE_cent_mean_tot_new[j-1,0]
    Corr_to_plot[0] = Corr_mean_tot_new[j-1,0]
    STD_to_plot[1] = STD_mean_tot_new[i,j]
    RMSE_cent_to_plot[1] = RMSE_cent_mean_tot_new[i,j]
    Corr_to_plot[1] = Corr_mean_tot_new[i,j]
    sm.taylor_diagram(STD_to_plot,RMSE_cent_to_plot,Corr_to_plot,\
                      markerLabelColor = 'black',markercolor = Color_per_biomes[j-1], \
                      markerSize=size_marker[i],symbol = symbol_list[i],edgewidth = 3,\
                      titleRMS = 'off', showlabelsRMS = 'off', tickRMS =[0.0],colCOR='grey',\
                      styleOBS='-',colOBS = Color_per_biomes[j-1],alpha=0.0)
    
plt.savefig('taylor_for_article_OSSE5_new.png',dpi=450,facecolor='w')

# %%
for j in np.arange(1,10,1):
    i = 5
    STD_to_plot = np.zeros(2)
    RMSE_cent_to_plot = np.zeros(2)
    Corr_to_plot = np.zeros(2)
    STD_to_plot[0] = STD_mean_tot_new[j-1,0]
    RMSE_cent_to_plot[0] = RMSE_cent_mean_tot_new[j-1,0]
    Corr_to_plot[0] = Corr_mean_tot_new[j-1,0]
    STD_to_plot[1] = STD_mean_tot_new[i,j]
    RMSE_cent_to_plot[1] = RMSE_cent_mean_tot_new[i,j]
    Corr_to_plot[1] = Corr_mean_tot_new[i,j]
    sm.taylor_diagram(STD_to_plot,RMSE_cent_to_plot,Corr_to_plot,\
                      markerLabelColor = 'black',markercolor = Color_per_biomes[j-1], \
                      markerSize=size_marker[i],symbol = symbol_list[i],edgewidth = 3,\
                      titleRMS = 'off', showlabelsRMS = 'off', tickRMS =[0.0],colCOR='grey',\
                      styleOBS='-',colOBS = Color_per_biomes[j-1],alpha=0.0)
    
plt.savefig('taylor_for_article_OSSE6_new.png',dpi=450,facecolor='w')

# %%
for j in np.arange(1,10,1):
    i = 6
    STD_to_plot = np.zeros(2)
    RMSE_cent_to_plot = np.zeros(2)
    Corr_to_plot = np.zeros(2)
    STD_to_plot[0] = STD_mean_tot_new[j-1,0]
    RMSE_cent_to_plot[0] = RMSE_cent_mean_tot_new[j-1,0]
    Corr_to_plot[0] = Corr_mean_tot_new[j-1,0]
    STD_to_plot[1] = STD_mean_tot_new[i,j]
    RMSE_cent_to_plot[1] = RMSE_cent_mean_tot_new[i,j]
    Corr_to_plot[1] = Corr_mean_tot_new[i,j]
    sm.taylor_diagram(STD_to_plot,RMSE_cent_to_plot,Corr_to_plot,\
                      markerLabelColor = 'black',markercolor = Color_per_biomes[j-1], \
                      markerSize=size_marker[i],symbol = symbol_list[i],edgewidth = 3,\
                      titleRMS = 'off', showlabelsRMS = 'off', tickRMS =[0.0],colCOR='grey',\
                      styleOBS='-',colOBS = Color_per_biomes[j-1],alpha=0.0)
    
plt.savefig('taylor_for_article_OSSE7_new.png',dpi=450,facecolor='w')

# %%
for j in np.arange(1,10,1):
    i = 7
    STD_to_plot = np.zeros(2)
    RMSE_cent_to_plot = np.zeros(2)
    Corr_to_plot = np.zeros(2)
    STD_to_plot[0] = STD_mean_tot_new[j-1,0]
    RMSE_cent_to_plot[0] = RMSE_cent_mean_tot_new[j-1,0]
    Corr_to_plot[0] = Corr_mean_tot_new[j-1,0]
    STD_to_plot[1] = STD_mean_tot_new[i,j]
    RMSE_cent_to_plot[1] = RMSE_cent_mean_tot_new[i,j]
    Corr_to_plot[1] = Corr_mean_tot_new[i,j]
    sm.taylor_diagram(STD_to_plot,RMSE_cent_to_plot,Corr_to_plot,\
                      markerLabelColor = 'black',markercolor = Color_per_biomes[j-1], \
                      markerSize=size_marker[i],symbol = symbol_list[i],edgewidth = 3,\
                      titleRMS = 'off', showlabelsRMS = 'off', tickRMS =[0.0],colCOR='grey',\
                      styleOBS='-',colOBS = Color_per_biomes[j-1],alpha=0.0)
    
plt.savefig('taylor_for_article_OSSE8_new.png',dpi=450,facecolor='w')

# %%
for j in np.arange(1,10,1):
    i = 8
    STD_to_plot = np.zeros(2)
    RMSE_cent_to_plot = np.zeros(2)
    Corr_to_plot = np.zeros(2)
    STD_to_plot[0] = STD_mean_tot_new[j-1,0]
    RMSE_cent_to_plot[0] = RMSE_cent_mean_tot_new[j-1,0]
    Corr_to_plot[0] = Corr_mean_tot_new[j-1,0]
    STD_to_plot[1] = STD_mean_tot_new[i,j]
    RMSE_cent_to_plot[1] = RMSE_cent_mean_tot_new[i,j]
    Corr_to_plot[1] = Corr_mean_tot_new[i,j]
    sm.taylor_diagram(STD_to_plot,RMSE_cent_to_plot,Corr_to_plot,\
                      markerLabelColor = 'black',markercolor = Color_per_biomes[j-1], \
                      markerSize=size_marker[i],symbol = symbol_list[i],edgewidth = 3,\
                      titleRMS = 'off', showlabelsRMS = 'off', tickRMS =[0.0],colCOR='grey',\
                      styleOBS='-',colOBS = Color_per_biomes[j-1],alpha=0.0)
    
plt.savefig('taylor_for_article_OSSE9_new.png',dpi=450,facecolor='w')

# %%
for j in np.arange(1,10,1):
    i = 9
    STD_to_plot = np.zeros(2)
    RMSE_cent_to_plot = np.zeros(2)
    Corr_to_plot = np.zeros(2)
    STD_to_plot[0] = STD_mean_tot_new[j-1,0]
    RMSE_cent_to_plot[0] = RMSE_cent_mean_tot_new[j-1,0]
    Corr_to_plot[0] = Corr_mean_tot_new[j-1,0]
    STD_to_plot[1] = STD_mean_tot_new[i,j]
    RMSE_cent_to_plot[1] = RMSE_cent_mean_tot_new[i,j]
    Corr_to_plot[1] = Corr_mean_tot_new[i,j]
    sm.taylor_diagram(STD_to_plot,RMSE_cent_to_plot,Corr_to_plot,\
                      markerLabelColor = 'black',markercolor = Color_per_biomes[j-1], \
                      markerSize=size_marker[i],symbol = symbol_list[i],edgewidth = 3,\
                      titleRMS = 'off', showlabelsRMS = 'off', tickRMS =[0.0],colCOR='grey',\
                      styleOBS='-',colOBS = Color_per_biomes[j-1],alpha=0.0)
    
plt.savefig('taylor_for_article_OSSE10_new.png',dpi=450,facecolor='w')

# %%
for j in np.arange(1,10,1):
    i = 10
    STD_to_plot = np.zeros(2)
    RMSE_cent_to_plot = np.zeros(2)
    Corr_to_plot = np.zeros(2)
    STD_to_plot[0] = STD_mean_tot_new[j-1,0]
    RMSE_cent_to_plot[0] = RMSE_cent_mean_tot_new[j-1,0]
    Corr_to_plot[0] = Corr_mean_tot_new[j-1,0]
    STD_to_plot[1] = STD_mean_tot_new[i,j]
    RMSE_cent_to_plot[1] = RMSE_cent_mean_tot_new[i,j]
    Corr_to_plot[1] = Corr_mean_tot_new[i,j]
    sm.taylor_diagram(STD_to_plot,RMSE_cent_to_plot,Corr_to_plot,\
                      markerLabelColor = 'black',markercolor = Color_per_biomes[j-1], \
                      markerSize=size_marker[i],symbol = symbol_list[i],edgewidth = 3,\
                      titleRMS = 'off', showlabelsRMS = 'off', tickRMS =[0.0],colCOR='grey',\
                      styleOBS='-',colOBS = Color_per_biomes[j-1],alpha=0.0)
    
plt.savefig('taylor_for_article_OSSE11_new.png',dpi=450,facecolor='w')

# %%
file_bias_mean = '/Users/annasommer/Documents/Documents/OSSE_Project/Data_for_plot/Bias_mean_TD.txt'

with open(file_bias_mean) as f:
        rows = [[str(x) for x in line.split(';')] for line in f]
        a,b,Bias_mean = [list(col) for col in zip(*rows)] 
        f.close()
        
file_bias_all = '/Users/annasommer/Documents/Documents/OSSE_Project/Data_for_plot/Bias_all_TD.txt'

with open(file_bias_all) as f:
        rows = [[str(x) for x in line.split(';')] for line in f]
        a,b,c,Bias_all = [list(col) for col in zip(*rows)] 
        f.close()
        
Bias_mean = np.array(Bias_mean)
Bias_mean = Bias_mean.astype(np.float)
Bias_all = np.array(Bias_all)
Bias_all = Bias_all.astype(np.float)

# %%
Bias_mean_tot = np.zeros((12,9))

Bias_all_tot = np.zeros((12,4,9))

                
for i in np.arange(0,12,1):
    p = 0
    for j in biome_numb:
        p = p + 1
        for k in np.arange(0,len(Corr_mean),1):
            if i == 0:
                Bias_mean_tot[i,p-1] = 0.
                break 
            if i == int(model_mean[k]) and j == int(biome_mean[k]):                
                Bias_mean_tot[i,p-1] = Bias_mean[k]
                break

for i in np.arange(0,12,1):
    p = 0
    for j in biome_numb:
        p = p + 1
        for n in np.arange(0,4,1):
            for k in np.arange(0,len(Bias_mean),1):
                if i == 0:
                    Bias_all_tot[i,n,p-1] = 0.
                    break 
                if i == int(model_mean[k]) and j == int(biome_mean[k]) and n == int(k_numb[k]):   
                    Bias_all_tot[i,n,p-1] = Bias_all[k]
                    break

# %%
for i in np.arange(0,9,1):
    sm.target_diagram(Bias_mean_tot[1:,i],RMSE_cent_mean_tot[1:,i],RMSE_mean_tot[1:,i],\
                      markerdisplayed = 'marker',markerSize = 10,markerLabel = Models_Name[1:],\
                      markerLabelColor = 'black',markerColor = Color_biomes[i], markerlegend = 'on',\
                      ticks = np.arange(-20,30,5),axismax = 25.0,circles = [5, 10, 15, 20, 25],alpha=0.0)
plt.savefig('target_legend.png',dpi=450,facecolor='w')

# %%
for i in np.arange(1,12,1):
    for j in np.arange(0,9,1):
        sm.target_diagram(Bias_mean_tot[i,j],RMSE_cent_mean_tot[i,j],RMSE_mean_tot[i,j],\
                          markerLabelColor = 'black',markerColor = Color_per_biomes[j],\
                          markerSize = size_marker[i-1],symbol = symbol_list[i-1],edgewidth = list_edgewidth[i-1],\
                          ticks = np.arange(-5,25,5),axismax = 20.0,circles = [5, 10, 15, 20],alpha=0.0)
plt.savefig('target_for_article.png',dpi=450,facecolor='w')

# %%
for i in np.arange(1,12,1):
    sm.target_diagram(Bias_mean_tot[i,0],RMSE_cent_mean_tot[i,0],RMSE_mean_tot[i,0],\
                      markerLabelColor = 'black',markerColor = Color_per_biomes[0],\
                      markerSize = size_marker[i-1],symbol = symbol_list[i-1],edgewidth = list_edgewidth[i-1],\
                      ticks = np.arange(-20,25,5),axismax = 20.0,circles = [5, 10, 15, 20],alpha=0.0)
plt.savefig('target_suppl_All.png',dpi=450,facecolor='w')

# %%
for i in np.arange(1,12,1):
    sm.target_diagram(Bias_mean_tot[i,1],RMSE_cent_mean_tot[i,1],RMSE_mean_tot[i,1],\
                      markerLabelColor = 'black',markerColor = Color_per_biomes[1],\
                      markerSize = size_marker[i-1],symbol = symbol_list[i-1],edgewidth = list_edgewidth[i-1],\
                      ticks = np.arange(-20,25,5),axismax = 20.0,circles = [5, 10, 15, 20],alpha=0.0)
plt.savefig('target_suppl_biome9.png',dpi=450,facecolor='w')

# %%
for i in np.arange(1,12,1):
    sm.target_diagram(Bias_mean_tot[i,2],RMSE_cent_mean_tot[i,2],RMSE_mean_tot[i,2],\
                      markerLabelColor = 'black',markerColor = Color_per_biomes[2],\
                      markerSize = size_marker[i-1],symbol = symbol_list[i-1],edgewidth = list_edgewidth[i-1],\
                      ticks = np.arange(-20,25,5),axismax = 20.0,circles = [5, 10, 15, 20],alpha=0.0)
plt.savefig('target_suppl_biome10.png',dpi=450,facecolor='w')

# %%
for i in np.arange(1,12,1):
    sm.target_diagram(Bias_mean_tot[i,3],RMSE_cent_mean_tot[i,3],RMSE_mean_tot[i,3],\
                      markerLabelColor = 'black',markerColor = Color_per_biomes[3],\
                      markerSize = size_marker[i-1],symbol = symbol_list[i-1],edgewidth = list_edgewidth[i-1],\
                      ticks = np.arange(-20,25,5),axismax = 20.0,circles = [5, 10, 15, 20],alpha=0.0)
plt.savefig('target_suppl_biome11.png',dpi=450,facecolor='w')

# %%
for i in np.arange(1,12,1):
    sm.target_diagram(Bias_mean_tot[i,4],RMSE_cent_mean_tot[i,4],RMSE_mean_tot[i,4],\
                      markerLabelColor = 'black',markerColor = Color_per_biomes[4],\
                      markerSize = size_marker[i-1],symbol = symbol_list[i-1],edgewidth = list_edgewidth[i-1],\
                      ticks = np.arange(-20,25,5),axismax = 20.0,circles = [5, 10, 15, 20],alpha=0.0)
plt.savefig('target_suppl_biome12.png',dpi=450,facecolor='w')

# %%
for i in np.arange(1,12,1):
    sm.target_diagram(Bias_mean_tot[i,5],RMSE_cent_mean_tot[i,5],RMSE_mean_tot[i,5],\
                      markerLabelColor = 'black',markerColor = Color_per_biomes[5],\
                      markerSize = size_marker[i-1],symbol = symbol_list[i-1],edgewidth = list_edgewidth[i-1],\
                      ticks = np.arange(-20,25,5),axismax = 20.0,circles = [5, 10, 15, 20],alpha=0.0)
plt.savefig('target_suppl_biome13.png',dpi=450,facecolor='w')

# %%
for i in np.arange(1,12,1):
    sm.target_diagram(Bias_mean_tot[i,6],RMSE_cent_mean_tot[i,6],RMSE_mean_tot[i,6],\
                      markerLabelColor = 'black',markerColor = Color_per_biomes[6],\
                      markerSize = size_marker[i-1],symbol = symbol_list[i-1],edgewidth = list_edgewidth[i-1],\
                      ticks = np.arange(-20,25,5),axismax = 20.0,circles = [5, 10, 15, 20],alpha=0.0)
plt.savefig('target_suppl_biome15.png',dpi=450,facecolor='w')

# %%
for i in np.arange(1,12,1):
    sm.target_diagram(Bias_mean_tot[i,7],RMSE_cent_mean_tot[i,7],RMSE_mean_tot[i,7],\
                      markerLabelColor = 'black',markerColor = Color_per_biomes[7],\
                      markerSize = size_marker[i-1],symbol = symbol_list[i-1],edgewidth = list_edgewidth[i-1],\
                      ticks = np.arange(-20,25,5),axismax = 20.0,circles = [5, 10, 15, 20],alpha=0.0)
plt.savefig('target_suppl_biome16.png',dpi=450,facecolor='w')

# %%
for i in np.arange(1,12,1):
    sm.target_diagram(Bias_mean_tot[i,8],RMSE_cent_mean_tot[i,8],RMSE_mean_tot[i,8],\
                      markerLabelColor = 'black',markerColor = Color_per_biomes[8],\
                      markerSize = size_marker[i-1],symbol = symbol_list[i-1],edgewidth = list_edgewidth[i-1],\
                      ticks = np.arange(-20,25,5),axismax = 20.0,circles = [5, 10, 15, 20],alpha=0.0)
plt.savefig('target_suppl_biome17.png',dpi=450,facecolor='w')

# %%
Color_per_biomes = ['fuchsia','cyan','palegreen','mediumseagreen','darkgreen','limegreen','orange','orangered','darkred']
kind = ['+','o','x','s','d','^','v','p','h','*','1']

linewidth_array = [12,8,12,8,8,8,8,8,8,12,8]

# %%
for i in np.arange(1,12,1):
    for j in np.arange(0,9,1):
        sm.target_diagram(Bias_mean_tot[i,j],RMSE_cent_mean_tot[i,j],RMSE_mean_tot[i,j],\
                          markerLabelColor = 'black',markerColor = Color_per_biomes[j],\
                          markerSize = size_marker[i-1],symbol = symbol_list[i-1],edgewidth = list_edgewidth[i-1],\
                          ticks = np.arange(-5,25,5),axismax = 20.0,circles = [5, 10, 15, 20],alpha=0.0)
plt.savefig('target_for_article.png',dpi=450,facecolor='w')

# %%
plt.figure(figsize=[14. , 14.])
for k in np.arange(0,9,1):
    for i in np.arange(1,12,1):
        if i == 1 or i == 3 or i == 11:
            plt.scatter(RMSE_cent_mean_tot[i,k], Bias_mean_tot[i,k],s = 4000, marker=kind[i-1],facecolor=Color_per_biomes[k], edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
        else:
            plt.scatter(RMSE_cent_mean_tot[i,k], Bias_mean_tot[i,k],s = 4000, marker=kind[i-1],facecolor='none', edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
#plot(Argo_number_lineplot, fCO2_diff_biomes_lineplot, 'go--', linewidth=2, markersize=12)
plt.xlabel('uRMSD,uatm',fontsize=35)
plt.ylabel('Bias, uatm',fontsize=35)
plt.xlim(1.,18.)
plt.ylim(-12.,5.)
locsX,labelsx = plt.xticks(size=35)    
locsY,labelsy = plt.yticks(size=35) 
plt.axhline(y=0, color='k')
circle1 = mpatches.Circle((0, 0), 4, color='k',ls='--', fill=False)
circle2 = mpatches.Circle((0, 0), 8, color='k',ls='--', fill=False)
circle3 = mpatches.Circle((0, 0), 12, color='k',ls='--', fill=False)
circle4 = mpatches.Circle((0, 0), 16, color='k',ls='--', fill=False)
circle5 = mpatches.Circle((0, 0), 20, color='k',ls='--', fill=False)
plt.gca().add_patch(circle1)
plt.gca().add_patch(circle2)
plt.gca().add_patch(circle3)
plt.gca().add_patch(circle4)
plt.gca().add_patch(circle5)
#plt.axvline(x=0, color='k')
#grid()
#plt.hlines(0.,-20.,400.,colors='k')
plt.savefig('Target_zoom_all.png',facecolor='w')

# %%
plt.figure(figsize=[14. , 14.])
for k in np.arange(0,1,1):
    for i in np.arange(1,12,1):
        if i == 1 or i == 3 or i == 11:
            plt.scatter(RMSE_cent_mean_tot[i,0], Bias_mean_tot[i,0],s = 4000, marker=kind[i-1],facecolor=Color_per_biomes[k], edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
        else:
            plt.scatter(RMSE_cent_mean_tot[i,0], Bias_mean_tot[i,0],s = 4000, marker=kind[i-1],facecolor='none', edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
#plot(Argo_number_lineplot, fCO2_diff_biomes_lineplot, 'go--', linewidth=2, markersize=12)
plt.xlabel('uRMSD,uatm',fontsize=35)
plt.ylabel('Bias, uatm',fontsize=35)
plt.xlim(1.,18.)
plt.ylim(-12.,5.)
locsX,labelsx = plt.xticks(size=35)    
locsY,labelsy = plt.yticks(size=35) 
plt.axhline(y=0, color='k')
circle1 = mpatches.Circle((0, 0), 4, color='k',ls='--', fill=False)
circle2 = mpatches.Circle((0, 0), 8, color='k',ls='--', fill=False)
circle3 = mpatches.Circle((0, 0), 12, color='k',ls='--', fill=False)
circle4 = mpatches.Circle((0, 0), 16, color='k',ls='--', fill=False)
circle5 = mpatches.Circle((0, 0), 20, color='k',ls='--', fill=False)
plt.gca().add_patch(circle1)
plt.gca().add_patch(circle2)
plt.gca().add_patch(circle3)
plt.gca().add_patch(circle4)
plt.gca().add_patch(circle5)
#plt.axvline(x=0, color='k')
#grid()
#plt.hlines(0.,-20.,400.,colors='k')
plt.savefig('Target_zoom_0.png',facecolor='w')

# %%
plt.figure(figsize=[14. , 14.])
for k in np.arange(1,2,1):
    for i in np.arange(1,12,1):
        if i == 1 or i == 3 or i == 11:
            plt.scatter(RMSE_cent_mean_tot[i,1], Bias_mean_tot[i,1],s = 4000, marker=kind[i-1],facecolor=Color_per_biomes[k], edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
        else:
            plt.scatter(RMSE_cent_mean_tot[i,1], Bias_mean_tot[i,1],s = 4000, marker=kind[i-1],facecolor='none', edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
#plot(Argo_number_lineplot, fCO2_diff_biomes_lineplot, 'go--', linewidth=2, markersize=12)
plt.xlabel('uRMSD,uatm',fontsize=35)
plt.ylabel('Bias, uatm',fontsize=35)
plt.xlim(1.,18.)
plt.ylim(-12.,5.)
locsX,labelsx = plt.xticks(size=35)    
locsY,labelsy = plt.yticks(size=35) 
plt.axhline(y=0, color='k')
circle1 = mpatches.Circle((0, 0), 4, color='k',ls='--', fill=False)
circle2 = mpatches.Circle((0, 0), 8, color='k',ls='--', fill=False)
circle3 = mpatches.Circle((0, 0), 12, color='k',ls='--', fill=False)
circle4 = mpatches.Circle((0, 0), 16, color='k',ls='--', fill=False)
circle5 = mpatches.Circle((0, 0), 20, color='k',ls='--', fill=False)
plt.gca().add_patch(circle1)
plt.gca().add_patch(circle2)
plt.gca().add_patch(circle3)
plt.gca().add_patch(circle4)
plt.gca().add_patch(circle5)
#plt.axvline(x=0, color='k')
#grid()
#plt.hlines(0.,-20.,400.,colors='k')
plt.savefig('Target_zoom_9.png',facecolor='w')

# %%
plt.figure(figsize=[14. , 14.])
for k in np.arange(2,3,1):
    for i in np.arange(1,12,1):
        if i == 1 or i == 3 or i == 11:
            plt.scatter(RMSE_cent_mean_tot[i,2], Bias_mean_tot[i,2],s = 4000, marker=kind[i-1],facecolor=Color_per_biomes[k], edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
        else:
            plt.scatter(RMSE_cent_mean_tot[i,2], Bias_mean_tot[i,2],s = 4000, marker=kind[i-1],facecolor='none', edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
#plot(Argo_number_lineplot, fCO2_diff_biomes_lineplot, 'go--', linewidth=2, markersize=12)
plt.xlabel('uRMSD,uatm',fontsize=35)
plt.ylabel('Bias, uatm',fontsize=35)
plt.xlim(1.,18.)
plt.ylim(-12.,5.)
locsX,labelsx = plt.xticks(size=35)    
locsY,labelsy = plt.yticks(size=35) 
plt.axhline(y=0, color='k')
circle1 = mpatches.Circle((0, 0), 4, color='k',ls='--', fill=False)
circle2 = mpatches.Circle((0, 0), 8, color='k',ls='--', fill=False)
circle3 = mpatches.Circle((0, 0), 12, color='k',ls='--', fill=False)
circle4 = mpatches.Circle((0, 0), 16, color='k',ls='--', fill=False)
circle5 = mpatches.Circle((0, 0), 20, color='k',ls='--', fill=False)
plt.gca().add_patch(circle1)
plt.gca().add_patch(circle2)
plt.gca().add_patch(circle3)
plt.gca().add_patch(circle4)
plt.gca().add_patch(circle5)
#plt.axvline(x=0, color='k')
#grid()
#plt.hlines(0.,-20.,400.,colors='k')
plt.savefig('Target_zoom_10.png',facecolor='w')

# %%
plt.figure(figsize=[14. , 14.])
for k in np.arange(3,4,1):
    for i in np.arange(1,12,1):
        if i == 1 or i == 3 or i == 11:
            plt.scatter(RMSE_cent_mean_tot[i,3], Bias_mean_tot[i,3],s = 4000, marker=kind[i-1],facecolor=Color_per_biomes[k], edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
        else:
            plt.scatter(RMSE_cent_mean_tot[i,3], Bias_mean_tot[i,3],s = 4000, marker=kind[i-1],facecolor='none', edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
#plot(Argo_number_lineplot, fCO2_diff_biomes_lineplot, 'go--', linewidth=2, markersize=12)
plt.xlabel('uRMSD,uatm',fontsize=35)
plt.ylabel('Bias, uatm',fontsize=35)
plt.xlim(1.,18.)
plt.ylim(-12.,5.)
locsX,labelsx = plt.xticks(size=35)    
locsY,labelsy = plt.yticks(size=35) 
plt.axhline(y=0, color='k')
circle1 = mpatches.Circle((0, 0), 4, color='k',ls='--', fill=False)
circle2 = mpatches.Circle((0, 0), 8, color='k',ls='--', fill=False)
circle3 = mpatches.Circle((0, 0), 12, color='k',ls='--', fill=False)
circle4 = mpatches.Circle((0, 0), 16, color='k',ls='--', fill=False)
circle5 = mpatches.Circle((0, 0), 20, color='k',ls='--', fill=False)
plt.gca().add_patch(circle1)
plt.gca().add_patch(circle2)
plt.gca().add_patch(circle3)
plt.gca().add_patch(circle4)
plt.gca().add_patch(circle5)
#plt.axvline(x=0, color='k')
#grid()
#plt.hlines(0.,-20.,400.,colors='k')
plt.savefig('Target_zoom_11.png',facecolor='w')

# %%
plt.figure(figsize=[14. , 14.])
for k in np.arange(4,5,1):
    for i in np.arange(1,12,1):
        if i == 1 or i == 3 or i == 11:
            plt.scatter(RMSE_cent_mean_tot[i,4], Bias_mean_tot[i,4],s = 4000, marker=kind[i-1],facecolor=Color_per_biomes[k], edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
        else:
            plt.scatter(RMSE_cent_mean_tot[i,4], Bias_mean_tot[i,4],s = 4000, marker=kind[i-1],facecolor='none', edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
#plot(Argo_number_lineplot, fCO2_diff_biomes_lineplot, 'go--', linewidth=2, markersize=12)
plt.xlabel('uRMSD,uatm',fontsize=35)
plt.ylabel('Bias, uatm',fontsize=35)
plt.xlim(1.,18.)
plt.ylim(-12.,5.)
locsX,labelsx = plt.xticks(size=35)    
locsY,labelsy = plt.yticks(size=35) 
plt.axhline(y=0, color='k')
circle1 = mpatches.Circle((0, 0), 4, color='k',ls='--', fill=False)
circle2 = mpatches.Circle((0, 0), 8, color='k',ls='--', fill=False)
circle3 = mpatches.Circle((0, 0), 12, color='k',ls='--', fill=False)
circle4 = mpatches.Circle((0, 0), 16, color='k',ls='--', fill=False)
circle5 = mpatches.Circle((0, 0), 20, color='k',ls='--', fill=False)
plt.gca().add_patch(circle1)
plt.gca().add_patch(circle2)
plt.gca().add_patch(circle3)
plt.gca().add_patch(circle4)
plt.gca().add_patch(circle5)
#plt.axvline(x=0, color='k')
#grid()
#plt.hlines(0.,-20.,400.,colors='k')
plt.savefig('Target_zoom_12.png',facecolor='w')

# %%
plt.figure(figsize=[14. , 14.])
for k in np.arange(5,6,1):
    for i in np.arange(1,12,1):
        if i == 1 or i == 3 or i == 11:
            plt.scatter(RMSE_cent_mean_tot[i,5], Bias_mean_tot[i,5],s = 4000, marker=kind[i-1],facecolor=Color_per_biomes[k], edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
        else:
            plt.scatter(RMSE_cent_mean_tot[i,5], Bias_mean_tot[i,5],s = 4000, marker=kind[i-1],facecolor='none', edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
#plot(Argo_number_lineplot, fCO2_diff_biomes_lineplot, 'go--', linewidth=2, markersize=12)
plt.xlabel('uRMSD,uatm',fontsize=35)
plt.ylabel('Bias, uatm',fontsize=35)
plt.xlim(1.,18.)
plt.ylim(-12.,5.)
locsX,labelsx = plt.xticks(size=35)    
locsY,labelsy = plt.yticks(size=35) 
plt.axhline(y=0, color='k')
circle1 = mpatches.Circle((0, 0), 4, color='k',ls='--', fill=False)
circle2 = mpatches.Circle((0, 0), 8, color='k',ls='--', fill=False)
circle3 = mpatches.Circle((0, 0), 12, color='k',ls='--', fill=False)
circle4 = mpatches.Circle((0, 0), 16, color='k',ls='--', fill=False)
circle5 = mpatches.Circle((0, 0), 20, color='k',ls='--', fill=False)
plt.gca().add_patch(circle1)
plt.gca().add_patch(circle2)
plt.gca().add_patch(circle3)
plt.gca().add_patch(circle4)
plt.gca().add_patch(circle5)
#plt.axvline(x=0, color='k')
#grid()
#plt.hlines(0.,-20.,400.,colors='k')
plt.savefig('Target_zoom_13.png',facecolor='w')

# %%
plt.figure(figsize=[14. , 14.])
for k in np.arange(6,7,1):
    for i in np.arange(1,12,1):
        if i == 1 or i == 3 or i == 11:
            plt.scatter(RMSE_cent_mean_tot[i,6], Bias_mean_tot[i,6],s = 4000, marker=kind[i-1],facecolor=Color_per_biomes[k], edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
        else:
            plt.scatter(RMSE_cent_mean_tot[i,6], Bias_mean_tot[i,6],s = 4000, marker=kind[i-1],facecolor='none', edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
#plot(Argo_number_lineplot, fCO2_diff_biomes_lineplot, 'go--', linewidth=2, markersize=12)
plt.xlabel('uRMSD,uatm',fontsize=35)
plt.ylabel('Bias, uatm',fontsize=35)
plt.xlim(1.,18.)
plt.ylim(-12.,5.)
locsX,labelsx = plt.xticks(size=35)    
locsY,labelsy = plt.yticks(size=35) 
plt.axhline(y=0, color='k')
circle1 = mpatches.Circle((0, 0), 4, color='k',ls='--', fill=False)
circle2 = mpatches.Circle((0, 0), 8, color='k',ls='--', fill=False)
circle3 = mpatches.Circle((0, 0), 12, color='k',ls='--', fill=False)
circle4 = mpatches.Circle((0, 0), 16, color='k',ls='--', fill=False)
circle5 = mpatches.Circle((0, 0), 20, color='k',ls='--', fill=False)
plt.gca().add_patch(circle1)
plt.gca().add_patch(circle2)
plt.gca().add_patch(circle3)
plt.gca().add_patch(circle4)
plt.gca().add_patch(circle5)
#plt.axvline(x=0, color='k')
#grid()
#plt.hlines(0.,-20.,400.,colors='k')
plt.savefig('Target_zoom_15.png',facecolor='w')

# %%
plt.figure(figsize=[14. , 14.])
for k in np.arange(7,8,1):
    for i in np.arange(1,12,1):
        if i == 1 or i == 3 or i == 11:
            plt.scatter(RMSE_cent_mean_tot[i,7], Bias_mean_tot[i,7],s = 4000, marker=kind[i-1],facecolor=Color_per_biomes[k], edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
        else:
            plt.scatter(RMSE_cent_mean_tot[i,7], Bias_mean_tot[i,7],s = 4000, marker=kind[i-1],facecolor='none', edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
#plot(Argo_number_lineplot, fCO2_diff_biomes_lineplot, 'go--', linewidth=2, markersize=12)
plt.xlabel('uRMSD,uatm',fontsize=35)
plt.ylabel('Bias, uatm',fontsize=35)
plt.xlim(1.,18.)
plt.ylim(-12.,5.)
locsX,labelsx = plt.xticks(size=35)    
locsY,labelsy = plt.yticks(size=35) 
plt.axhline(y=0, color='k')
circle1 = mpatches.Circle((0, 0), 4, color='k',ls='--', fill=False)
circle2 = mpatches.Circle((0, 0), 8, color='k',ls='--', fill=False)
circle3 = mpatches.Circle((0, 0), 12, color='k',ls='--', fill=False)
circle4 = mpatches.Circle((0, 0), 16, color='k',ls='--', fill=False)
circle5 = mpatches.Circle((0, 0), 20, color='k',ls='--', fill=False)
plt.gca().add_patch(circle1)
plt.gca().add_patch(circle2)
plt.gca().add_patch(circle3)
plt.gca().add_patch(circle4)
plt.gca().add_patch(circle5)
#plt.axvline(x=0, color='k')
#grid()
#plt.hlines(0.,-20.,400.,colors='k')
plt.savefig('Target_zoom_16.png',facecolor='w')

# %%
plt.figure(figsize=[14. , 14.])
for k in np.arange(8,9,1):
    for i in np.arange(1,12,1):
        if i == 1 or i == 3 or i == 11:
            plt.scatter(RMSE_cent_mean_tot[i,8], Bias_mean_tot[i,8],s = 4000, marker=kind[i-1],facecolor=Color_per_biomes[k], edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
        else:
            plt.scatter(RMSE_cent_mean_tot[i,8], Bias_mean_tot[i,8],s = 4000, marker=kind[i-1],facecolor='none', edgecolors=Color_per_biomes[k],linewidth=linewidth_array[i-1])
#plot(Argo_number_lineplot, fCO2_diff_biomes_lineplot, 'go--', linewidth=2, markersize=12)
plt.xlabel('uRMSD,uatm',fontsize=35)
plt.ylabel('Bias, uatm',fontsize=35)
plt.xlim(1.,18.)
plt.ylim(-12.,5.)
locsX,labelsx = plt.xticks(size=35)    
locsY,labelsy = plt.yticks(size=35) 
plt.axhline(y=0, color='k')
circle1 = mpatches.Circle((0, 0), 4, color='k',ls='--', fill=False)
circle2 = mpatches.Circle((0, 0), 8, color='k',ls='--', fill=False)
circle3 = mpatches.Circle((0, 0), 12, color='k',ls='--', fill=False)
circle4 = mpatches.Circle((0, 0), 16, color='k',ls='--', fill=False)
circle5 = mpatches.Circle((0, 0), 20, color='k',ls='--', fill=False)
plt.gca().add_patch(circle1)
plt.gca().add_patch(circle2)
plt.gca().add_patch(circle3)
plt.gca().add_patch(circle4)
plt.gca().add_patch(circle5)
#plt.axvline(x=0, color='k')
#grid()
#plt.hlines(0.,-20.,400.,colors='k')
plt.savefig('Target_zoom_17.png',facecolor='w')
